# %%
import warnings

warnings.filterwarnings("ignore")

import sys
import os

# 配置搜索路径
sys.path.append("./")
sys.path.append("../")
sys.path.append("../../")
import backtrader as bt
import pandas as pd
import numpy as np
import pprint
import sqlite3
import math
from tqdm import tqdm
from datetime import datetime
from Offline.strategies.ml_based_strategy_latest_回归策略 import CustomMLStrategy
# from Offline.strategies.ml_based_strategy_latest_回归策略_v2 import CustomMLStrategy
from backtest_utils import CustomCommissionSchema, CustomAnalyzer

from Share.database_auto.db_data_downloader.downloader_base import DownloaderBase
import Share.database_auto.database_config as db_config

# %%
BACKTEST_INDEX_SYMBOLS = "000016"  # 【选股】策略的对比基准=指数index，【择时】策略的对比基准=单股自身
# ---- 回归任务
model_pred_df = pd.read_pickle(f'./backtest_data/test/{BACKTEST_INDEX_SYMBOLS}_2019-01-01_回归任务_v5.pkl')
# model_pred_df = pd.read_pickle(f'./backtest_data/test/000016_2019-01-01_回归任务_v7_online.pkl')

# %%
model_pred_df.head()
# Out:
#      stock_code stock_name    datetime     label  label_pred
# 2019  sh.600028       中国石化  2019-01-02  0.564382    0.465099
# 2020  sh.600028       中国石化  2019-01-03  0.563441    0.403107
# 2021  sh.600028       中国石化  2019-01-04  0.548934    0.391665
# 2022  sh.600028       中国石化  2019-01-07  0.537382    0.380563
# 2023  sh.600028       中国石化  2019-01-08  0.532780    0.386130

# %%
# model_pred_df = model_pred_df[model_pred_df['stock_code'] == 'sh.600028']
# model_pred_df = model_pred_df[model_pred_df['datetime'] <= '2019-01-30']

# %%
# 构建数据里表
BACKTEST_STOCK_SYMBOLS = model_pred_df['stock_code'].unique().tolist()
print(BACKTEST_STOCK_SYMBOLS)
BACKTEST_START_DATE = model_pred_df['datetime'].min()  # 回测开始日期
BACKTEST_END_DATE = model_pred_df['datetime'].max()  # 回测结束日期
print(f'StartDate: {BACKTEST_START_DATE}, EndDate: {BACKTEST_END_DATE}')
# Out:
# ['sh.600028', 'sh.600031', 'sh.600036', 'sh.600048', 'sh.600050', 'sh.600089', 'sh.600104', 'sh.600111', 'sh.600150', 'sh.600276', 'sh.600309', 'sh.600406', 'sh.600436', 'sh.600438', 'sh.600519', 'sh.600690', 'sh.600809', 'sh.600887', 'sh.600893', 'sh.600900', 'sh.601012', 'sh.601088', 'sh.601166', 'sh.601225', 'sh.601288', 'sh.601318', 'sh.601390', 'sh.601398', 'sh.601601', 'sh.601628', 'sh.601633', 'sh.601668', 'sh.601669', 'sh.601857', 'sh.601888', 'sh.601899', 'sh.601919', 'sh.601988', 'sh.603259', 'sh.603288', 'sh.603501', 'sh.603799', 'sh.603986']
# StartDate: 2019-01-02, EndDate: 2019-01-30

# %%
# 初始化db_downloader
db_conn = sqlite3.connect("../../Share/database_auto/hh_quant_auto.db")
db_downloader = DownloaderBase(db_conn=db_conn, db_config=db_config)
dd = db_downloader._download_all_stock_info()
dd[dd['code'] == f'sh.{BACKTEST_INDEX_SYMBOLS}']
# Out:
#           code code_name     in_date out_date type status industry
# 985  sh.000016    上证50指数  2004-01-02            指数     上市     None

# %%
# 初始化backtrader相关参数
cerebro = bt.Cerebro()
BACKTEST_INITIAL_CASH = 200000  # 初始化资金

print("开始设置回测基础参数...")
cerebro.broker.setcash(BACKTEST_INITIAL_CASH)  # 配置初始资金量
cerebro.broker.addcommissioninfo(CustomCommissionSchema())  # 配置自定义的佣金类型
cerebro.broker.set_slippage_perc(perc=0.0001) # 配置自定义的滑点类型

# 获取回测区间的所有交易日期来构建统一的Index索引
BACKTEST_DATETIME_INDEX = pd.to_datetime(sorted(model_pred_df['datetime'].unique()))

print("开始添加回测股票数据...")
for stock_symbol in tqdm(BACKTEST_STOCK_SYMBOLS):
    stock_data = db_downloader._download_history_base_info(stock_symbol, start_date=BACKTEST_START_DATE, end_date=BACKTEST_END_DATE)
    if not stock_data.empty:
        stock_data = stock_data[["datetime", "open", "high", "low", "close", "volume"]]
        stock_data["datetime"] = pd.to_datetime(stock_data["datetime"])
        stock_data = stock_data.set_index("datetime").reindex(BACKTEST_DATETIME_INDEX).fillna(method='ffill')
        stock_data_feeds = bt.feeds.PandasData(dataname=stock_data)  # 构建回测数据Feeds流
        cerebro.adddata(stock_data_feeds, name=stock_symbol)  # 添加回测数据

print("开始添加基准数据...")
BENCHMARK_SYMBOLS = 'sh.' + BACKTEST_INDEX_SYMBOLS
benchmark_data = db_downloader._download_history_base_info(BENCHMARK_SYMBOLS, start_date=BACKTEST_START_DATE, end_date=BACKTEST_END_DATE)
benchmark_data = benchmark_data[["datetime", "open", "high", "low", "close", "volume"]]
benchmark_data["datetime"] = pd.to_datetime(benchmark_data["datetime"])
benchmark_data = benchmark_data.set_index("datetime").reindex(BACKTEST_DATETIME_INDEX).fillna(method='ffill')
benchmark_name = f"benchmark_{BENCHMARK_SYMBOLS}"
benchmark_data_feeds = bt.feeds.PandasData(dataname=benchmark_data)  # 构建基准数据Feeds流
cerebro.adddata(benchmark_data_feeds, name=benchmark_name)  # 添加基准数据

print("开始添加分析器...")
cerebro.addanalyzer(bt.analyzers.DrawDown, _name="drawdown")  # 添加最大回撤的分析器，后续customAnalyzer中需要用到
cerebro.addanalyzer(CustomAnalyzer, _name="custom_analyzer")  # 添加自定义的分析器

# print("开始添加观察器...")
# cerebro.addobserver(bt.observers.Benchmark, data=benchmark_data_feeds, timeframe=bt.TimeFrame.NoTimeFrame)  # 添加基准对比观察器
# Out:
# 开始设置回测基础参数...
# 开始添加回测股票数据...
# 100%|██████████| 43/43 [00:00<00:00, 437.40it/s]
# 开始添加基准数据...
# 开始添加分析器...

# %%
print("开始添加策略...")
strategy_params = {
    "benchmark": benchmark_name,
    "model_pred_dataframe": model_pred_df,
}

lower_bound, upper_boumd = np.nanquantile(model_pred_df['label_pred'], [0.2, 0.8])
print(f"lower_bound: {lower_bound}, upper_bound: {upper_boumd}")

strategy_params.update(
    {
        "max_position_proportion": 0.15,  # 最大持仓资金占比
        "min_holding_period": 0,  # 最小持仓周期
        "max_holding_period": 20,  # 最大持仓周期
        "top_n": 5,  # 每日选择股票的TopN
        "min_buy_cash": 2000,  # 最小购买资金限制
        "atr_period": 14,  # ATR计算周期
         "init_trailing_stop_loss_factor": 1.5,  # 首次买入跟踪止损位 = 1.5ATR
        "update_trailing_stop_loss_factor": 1,  # 更新跟踪止损位 = 1ATR
        "atr_risk": 0.05,  # ATR风险系数
        "buy_pred_upper_bound": upper_boumd,
        "sell_pred_lower_bound": lower_bound
    }
)

cerebro.addstrategy(CustomMLStrategy, **strategy_params)
# Out:
# 开始添加策略...
# lower_bound: 0.37900925874710084, upper_bound: 0.4289488673210144
# 0

# %%
print("开始运行回测...")
# 运行回测
results = cerebro.run()
# 打印初始资金
print(f"Start Portfolio Value: {BACKTEST_INITIAL_CASH}")
# 打印最终资金
print(f"Final Portfolio Value: {cerebro.broker.getvalue()}")
# Out:
# 开始运行回测...
# 启动基准对比...
# 回测数据共: 43
# current_date: 2019-01-02 ================================================================================
# current_cash: 200000.0
# symbol: sh.600028, today_atr:0.23390259704961536, base_size: 2652, atr_size: 6412, final_size: 2700
# symbol: sh.601899, today_atr:0.08588928660980663, base_size: 5268, atr_size: 17464, final_size: 5300
# symbol: sh.603799, today_atr:1.3888343287279394, base_size: 722, atr_size: 1080, final_size: 700
# symbol: sh.600893, today_atr:1.460523221797085, base_size: 448, atr_size: 1027, final_size: 400
# symbol: sh.603501, today_atr:1.324209590689633, base_size: 1033, atr_size: 1132, final_size: 1000
# 2019-01-03 买入执行, 引用: 1, 价格: 11.36, 成本: 30666.16, 手续费: 5.00, 数量: 2700.00, 股票: sh.600028
# 2019-01-03 买入执行, 引用: 2, 价格: 5.60, 成本: 29680.32, 手续费: 5.00, 数量: 5300.00, 股票: sh.601899
# 2019-01-03 买入执行, 引用: 3, 价格: 41.44, 成本: 29006.91, 手续费: 5.00, 数量: 700.00, 股票: sh.603799
# 2019-01-03 买入执行, 引用: 4, 价格: 66.83, 成本: 26730.67, 手续费: 5.00, 数量: 400.00, 股票: sh.600893
# 2019-01-03 买入执行, 引用: 5, 价格: 28.87, 成本: 28873.49, 手续费: 5.00, 数量: 1000.00, 股票: sh.603501
# current_date: 2019-01-03 ================================================================================
# current_cash: 55017.455695
# symbol: sh.601633, today_atr:0.7827416904175772, base_size: 567, atr_size: 707, final_size: 600
# symbol: sh.600900, today_atr:0.6448227147093042, base_size: 276, atr_size: 840, final_size: 300
# 2019-01-04 卖出执行, 引用: 6, 价格: 5.75, 成本: 29680.32, 手续费: 30.57, 数量: -5300.00, 股票: sh.601899
# 2019-01-04 买入执行, 引用: 7, 价格: 19.34, 成本: 11603.54, 手续费: 5.00, 数量: 600.00, 股票: sh.601633
# 2019-01-04 买入执行, 引用: 8, 价格: 39.14, 成本: 11743.29, 手续费: 5.00, 数量: 300.00, 股票: sh.600900
# 2019-01-04 操作盈亏, 毛利润: 795.87, 净利润: 760.31, 股票: sh.601899
# current_date: 2019-01-04 ================================================================================
# current_cash: 62106.249912347754
# symbol: sh.600089, today_atr:4.920958787901597, base_size: 56, atr_size: 130, final_size: 100
# symbol: sh.601919, today_atr:0.14697091405954973, base_size: 2821, atr_size: 4294, final_size: 2800
# symbol: sh.600900, today_atr:0.6448227147093042, base_size: 323, atr_size: 966, final_size: 300
# symbol: sh.600406, today_atr:11.24998792676505, base_size: 28, atr_size: 53, final_size: 0
# 2019-01-07 买入执行, 引用: 9, 价格: 227.45, 成本: 22745.13, 手续费: 5.00, 数量: 100.00, 股票: sh.600089
# 2019-01-07 买入执行, 引用: 10, 价格: 4.47, 成本: 12528.45, 手续费: 5.00, 数量: 2800.00, 股票: sh.601919
# 2019-01-07 买入执行, 引用: 11, 价格: 38.75, 成本: 11623.61, 手续费: 5.00, 数量: 300.00, 股票: sh.600900
# current_date: 2019-01-07 ================================================================================
# current_cash: 15194.05066134776
# symbol: sh.601919, today_atr:0.14697091405954973, base_size: 692, atr_size: 1071, final_size: 700
# symbol: sh.600900, today_atr:0.6448227147093042, base_size: 80, atr_size: 238, final_size: 100
# symbol: sh.600089, today_atr:4.920958787901597, base_size: 13, atr_size: 31, final_size: 0
# symbol: sh.601633, today_atr:0.7827416904175772, base_size: 145, atr_size: 187, final_size: 100
# 2019-01-08 买入执行, 引用: 12, 价格: 4.54, 成本: 3175.87, 手续费: 5.00, 数量: 700.00, 股票: sh.601919
# 2019-01-08 买入执行, 引用: 13, 价格: 38.27, 成本: 3826.70, 手续费: 5.00, 数量: 100.00, 股票: sh.600900
# 2019-01-08 买入执行, 引用: 14, 价格: 20.04, 成本: 2003.87, 手续费: 5.00, 数量: 100.00, 股票: sh.601633
# current_date: 2019-01-08 ================================================================================
# current_cash: 6172.6101073477585
# current_date: 2019-01-09 ================================================================================
# current_cash: 6172.6101073477585
# 2019-01-10 卖出执行, 引用: 15, 价格: 41.49, 成本: 29006.91, 手续费: 29.13, 数量: -700.00, 股票: sh.603799
# 2019-01-10 操作盈亏, 毛利润: 33.89, 净利润: -0.24, 股票: sh.603799
# current_date: 2019-01-10 ================================================================================
# current_cash: 35184.27781933086
# symbol: sh.601919, today_atr:0.14697091405954973, base_size: 3017, atr_size: 4881, final_size: 3000
# symbol: sh.600150, today_atr:0.9566925014151894, base_size: 512, atr_size: 904, final_size: 500
# 2019-01-11 买入执行, 引用: 16, 价格: 4.74, 成本: 14205.52, 手续费: 5.00, 数量: 3000.00, 股票: sh.601919
# 2019-01-11 买入执行, 引用: 17, 价格: 33.94, 成本: 16968.80, 手续费: 5.00, 数量: 500.00, 股票: sh.600150
# current_date: 2019-01-11 ================================================================================
# current_cash: 3999.9606993308626
# current_date: 2019-01-14 ================================================================================
# current_cash: 3999.9606993308626
# 2019-01-15 卖出执行, 引用: 18, 价格: 28.07, 成本: 28873.49, 手续费: 28.15, 数量: -1000.00, 股票: sh.603501
# 2019-01-15 卖出执行, 引用: 19, 价格: 38.46, 成本: 27193.60, 手续费: 27.00, 数量: -700.00, 股票: sh.600900
# 2019-01-15 操作盈亏, 毛利润: -803.69, 净利润: -836.84, 股票: sh.603501
# 2019-01-15 操作盈亏, 毛利润: -271.08, 净利润: -313.08, 股票: sh.600900
# current_date: 2019-01-15 ================================================================================
# current_cash: 58937.13087287043
# symbol: sh.603501, today_atr:1.324209590689633, base_size: 402, atr_size: 443, final_size: 400
# symbol: sh.600150, today_atr:0.9566925014151894, base_size: 330, atr_size: 609, final_size: 300
# symbol: sh.601633, today_atr:0.7827416904175772, base_size: 544, atr_size: 735, final_size: 500
# 2019-01-16 买入执行, 引用: 20, 价格: 29.91, 成本: 11965.88, 手续费: 5.00, 数量: 400.00, 股票: sh.603501
# 2019-01-16 买入执行, 引用: 21, 价格: 35.31, 成本: 10591.51, 手续费: 5.00, 数量: 300.00, 股票: sh.600150
# 2019-01-16 买入执行, 引用: 22, 价格: 21.16, 成本: 10578.91, 手续费: 5.00, 数量: 500.00, 股票: sh.601633
# current_date: 2019-01-16 ================================================================================
# current_cash: 25785.83757487043
# symbol: sh.600150, today_atr:0.9566925014151894, base_size: 75, atr_size: 139, final_size: 100
# symbol: sh.601633, today_atr:0.7827416904175772, base_size: 235, atr_size: 322, final_size: 200
# symbol: sh.601899, today_atr:0.08588928660980663, base_size: 882, atr_size: 2905, final_size: 900
# symbol: sh.603501, today_atr:1.324209590689633, base_size: 168, atr_size: 186, final_size: 200
# 2019-01-17 买入执行, 引用: 23, 价格: 35.28, 成本: 3528.01, 手续费: 5.00, 数量: 100.00, 股票: sh.600150
# 2019-01-17 买入执行, 引用: 24, 价格: 21.33, 成本: 4266.53, 手续费: 5.00, 数量: 200.00, 股票: sh.601633
# 2019-01-17 买入执行, 引用: 25, 价格: 5.68, 成本: 5108.19, 手续费: 5.00, 数量: 900.00, 股票: sh.601899
# 2019-01-17 买入执行, 引用: 26, 价格: 29.84, 成本: 5968.94, 手续费: 5.00, 数量: 200.00, 股票: sh.603501
# current_date: 2019-01-17 ================================================================================
# current_cash: 6894.17059687043
# 2019-01-18 卖出执行, 引用: 27, 价格: 224.92, 成本: 22745.13, 手续费: 22.56, 数量: -100.00, 股票: sh.600089
# 2019-01-18 操作盈亏, 毛利润: -253.42, 净利润: -280.98, 股票: sh.600089
# current_date: 2019-01-18 ================================================================================
# current_cash: 29363.322015134618
# symbol: sh.601398, today_atr:0.1408114769897035, base_size: 617, atr_size: 2012, final_size: 600
# symbol: sh.601899, today_atr:0.08588928660980663, base_size: 984, atr_size: 3286, final_size: 1000
# symbol: sh.600438, today_atr:4.230041377769777, base_size: 61, atr_size: 65, final_size: 100
# 2019-01-21 买入执行, 引用: 28, 价格: 9.21, 成本: 5523.61, 手续费: 5.00, 数量: 600.00, 股票: sh.601398
# 2019-01-21 买入执行, 引用: 29, 价格: 5.73, 成本: 5731.90, 手续费: 5.00, 数量: 1000.00, 股票: sh.601899
# 2019-01-21 买入执行, 引用: 30, 价格: 90.34, 成本: 9034.03, 手续费: 5.00, 数量: 100.00, 股票: sh.600438
# current_date: 2019-01-21 ================================================================================
# current_cash: 9058.776396134617
# 2019-01-22 卖出执行, 引用: 31, 价格: 32.02, 成本: 31088.32, 手续费: 28.90, 数量: -900.00, 股票: sh.600150
# 2019-01-22 操作盈亏, 毛利润: -2273.29, 净利润: -2317.19, 股票: sh.600150
# current_date: 2019-01-22 ================================================================================
# current_cash: 37844.90313184099
# symbol: sh.600150, today_atr:0.9566925014151894, base_size: 249, atr_size: 423, final_size: 200
# symbol: sh.601899, today_atr:0.08588928660980663, base_size: 1315, atr_size: 4317, final_size: 1300
# symbol: sh.600438, today_atr:4.230041377769777, base_size: 84, atr_size: 86, final_size: 100
# symbol: sh.603799, today_atr:1.3888343287279394, base_size: 173, atr_size: 259, final_size: 200
# 2019-01-23 买入执行, 引用: 32, 价格: 32.32, 成本: 6464.29, 手续费: 5.00, 数量: 200.00, 股票: sh.600150
# 2019-01-23 买入执行, 引用: 33, 价格: 5.66, 成本: 7353.06, 手续费: 5.00, 数量: 1300.00, 股票: sh.601899
# 2019-01-23 买入执行, 引用: 34, 价格: 86.36, 成本: 8635.61, 手续费: 5.00, 数量: 100.00, 股票: sh.600438
# 2019-01-23 买入执行, 引用: 35, 价格: 41.23, 成本: 8245.18, 手续费: 5.00, 数量: 200.00, 股票: sh.603799
# current_date: 2019-01-23 ================================================================================
# current_cash: 7126.758856840988
# current_date: 2019-01-24 ================================================================================
# current_cash: 7126.758856840988
# current_date: 2019-01-25 ================================================================================
# current_cash: 7126.758856840988
# 2019-01-28 卖出执行, 引用: 36, 价格: 4.59, 成本: 29909.84, 手续费: 29.91, 数量: -6500.00, 股票: sh.601919
# 2019-01-28 操作盈亏, 毛利润: -86.27, 净利润: -131.19, 股票: sh.601919
# current_date: 2019-01-28 ================================================================================
# current_cash: 36920.41316379395
# symbol: sh.601919, today_atr:0.14697091405954973, base_size: 1720, atr_size: 2649, final_size: 1700
# symbol: sh.601899, today_atr:0.08588928660980663, base_size: 1353, atr_size: 4455, final_size: 1400
# symbol: sh.600150, today_atr:0.9566925014151894, base_size: 221, atr_size: 381, final_size: 200
# symbol: sh.601012, today_atr:8.240304759999255, base_size: 41, atr_size: 43, final_size: 0
# symbol: sh.601398, today_atr:0.1408114769897035, base_size: 755, atr_size: 2510, final_size: 800
# 2019-01-29 买入执行, 引用: 37, 价格: 4.54, 成本: 7712.82, 手续费: 5.00, 数量: 1700.00, 股票: sh.601919
# 2019-01-29 买入执行, 引用: 38, 价格: 5.66, 成本: 7918.68, 手续费: 5.00, 数量: 1400.00, 股票: sh.601899
# 2019-01-29 买入执行, 引用: 39, 价格: 32.92, 成本: 6583.64, 手续费: 5.00, 数量: 200.00, 股票: sh.600150
# 2019-01-29 买入执行, 引用: 40, 价格: 9.38, 成本: 7500.99, 手续费: 5.00, 数量: 800.00, 股票: sh.601398
# current_date: 2019-01-29 ================================================================================
# current_cash: 7184.283636793948
# 2019-01-30 卖出执行, 引用: 41, 价格: 37.62, 成本: 8245.18, 手续费: 7.55, 数量: -200.00, 股票: sh.603799
# 2019-01-30 卖出执行, 引用: 42, 价格: 68.74, 成本: 26730.67, 手续费: 27.58, 数量: -400.00, 股票: sh.600893
# 2019-01-30 卖出执行, 引用: 43, 价格: 29.42, 成本: 17934.81, 手续费: 17.70, 数量: -600.00, 股票: sh.603501
# 2019-01-30 卖出执行, 引用: 44, 价格: 31.97, 成本: 13047.92, 手续费: 12.83, 数量: -400.00, 股票: sh.600150
# 2019-01-30 操作盈亏, 毛利润: -721.18, 净利润: -733.72, 股票: sh.603799
# 2019-01-30 操作盈亏, 毛利润: 765.70, 净利润: 733.12, 股票: sh.600893
# 2019-01-30 操作盈亏, 毛利润: -283.86, 净利润: -311.56, 股票: sh.603501
# 2019-01-30 操作盈亏, 毛利润: -261.12, 净利润: -283.95, 股票: sh.600150
# current_date: 2019-01-30 ================================================================================
# current_cash: 72576.76266086135
# symbol: sh.603799, today_atr:1.3888343287279394, base_size: 391, atr_size: 533, final_size: 400
# symbol: sh.601398, today_atr:0.1408114769897035, base_size: 1552, atr_size: 5205, final_size: 1600
# symbol: sh.601899, today_atr:0.08588928660980663, base_size: 861, atr_size: 2818, final_size: 900
# symbol: sh.603259, today_atr:1.848068791926318, base_size: 187, atr_size: 386, final_size: 200
# symbol: sh.601225, today_atr:0.19288268145132542, base_size: 1554, atr_size: 3675, final_size: 1600
# Start Portfolio Value: 200000
# Final Portfolio Value: 204574.29266086133

# %%
# cerebro.plot()[0][0]

# %%
print("开始打印回测相关指标...")
# 打印初始资金
print(f"Start Portfolio Value: {BACKTEST_INITIAL_CASH}")
# 打印最终资金
print(f"Final Portfolio Value: {cerebro.broker.get_value()}")

def plot_strategy_benchmark_returns(strategy_returns, benchmark_returns):
    import matplotlib.pyplot as plt
    # 检查index是否一致以保证对齐
    if not strategy_returns.index.equals(benchmark_returns.index):
        raise ValueError("Indexes of strategy_returns and benchmark_returns must match")
    # 计算累积收益率
    strategy_cumulative_returns = (1 + strategy_returns).cumprod() - 1
    benchmark_cumulative_returns = (1 + benchmark_returns).cumprod() - 1
    # 绘制累积收益率曲线
    plt.figure(figsize=(10,4))
    plt.plot(strategy_cumulative_returns, label='Strategy')
    plt.plot(benchmark_cumulative_returns, label='Benchmark')
    # 添加标题和标签
    plt.title('Strategy vs Benchmark Cumulative Returns')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Returns')
    # 显示图例
    plt.legend()
    # 显示网格
    plt.grid(True)
    # 显示绘制的图形
    plt.show()

custom_analysis = results[0].analyzers.custom_analyzer.get_analysis()
format_analysis_result = {"基准": {}, "策略": {}, "其他": {}}
for key, value in custom_analysis.items():
    if key.startswith("基准"):
        format_analysis_result["基准"][key] = round(value, 4)
    elif key.startswith("策略"):
        format_analysis_result["策略"][key] = round(value, 4)
    else:
        format_analysis_result["其他"][key] = round(value, 4)
pprint.pprint(format_analysis_result)

strategy_returns = pd.Series(results[0].analyzers.custom_analyzer.get_strategy_returns(), index=benchmark_data.index[1:])
benchmark_returns = pd.Series(results[0].analyzers.custom_analyzer.get_benchmark_returns(), index=benchmark_data.index[1:])
plot_strategy_benchmark_returns(strategy_returns, benchmark_returns)
# Out:
# 开始打印回测相关指标...
# Start Portfolio Value: 200000
# Final Portfolio Value: 204574.29266086133
# {'其他': {'亏损次数': 8,
#         '夏普比率': 1.8221,
#         '日均超额收益': -0.0026,
#         '日胜率': 0.65,
#         '最大回撤': 3.1968,
#         '最大回撤区间': 13,
#         '盈亏比': 0.8588,
#         '盈利次数': 3,
#         '索提诺比率': 2.6878,
#         '胜率': 0.2727,
#         '贝塔': 0.6153,
#         '超额收益': -0.0554,
#         '超额收益夏普比率': -4.5127,
#         '阿尔法': -0.0012},
#  '基准': {'基准年化收益': 1.4716, '基准收益': 0.0783, '基准波动率': 0.1497},
#  '策略': {'策略年化收益': 0.3118, '策略收益': 0.0229, '策略波动率': 0.1639}}

# %%
annual_strategy_returns = strategy_returns.resample('Y').apply(lambda x: (1 + x).prod() - 1)
annual_benchmark_returns = benchmark_returns.resample('Y').apply(lambda x: (1 + x).prod() - 1)
annual_returns = pd.concat([annual_strategy_returns, annual_benchmark_returns], axis=1)
annual_returns.columns = ['Strategy', 'Benchmark']
annual_returns['Gap'] = annual_returns['Strategy'] - annual_returns['Benchmark']
annual_returns
# Out:
#             Strategy  Benchmark      Gap
# 2019-12-31  0.022871   0.078321 -0.05545

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_head_map(monthly_returns, name=''):
    monthly_returns_df = monthly_returns.to_frame(name='monthly_returns')
    # 创建新的列来代表年份和月份
    monthly_returns_df['Year'] = monthly_returns_df.index.year
    monthly_returns_df['Month'] = monthly_returns_df.index.month

    # 使用pivot方法来创建适合热力图的DataFrame
    pivot_table = monthly_returns_df.pivot(index='Year', columns='Month', values='monthly_returns')

    # 使用Seaborn绘制热力图
    plt.figure(figsize=(14, 6))
    sns.heatmap(pivot_table, annot=True, fmt=".2%",cmap='coolwarm', center=0)
    plt.title(name)
    plt.ylabel('Year')
    plt.xlabel('Month')
    plt.show()

# 假设 monthly_returns 是一个包含月度收益率的Series，并且它的索引是DateTimeIndex
# 如果它不是DataFrame，我们先将其转换成DataFrame
strategy_monthly_returns = strategy_returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
benchmark_monthly_returns = benchmark_returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
extra_monthly_returns = strategy_monthly_returns - benchmark_monthly_returns

plot_head_map(benchmark_monthly_returns, 'BenchMark Monthly Returns')
plot_head_map(strategy_monthly_returns, 'Strategy Monthly Returns')
plot_head_map(extra_monthly_returns, 'Extra Monthly Returns')

# %%
# !nvidia-smi

# %%
# import pandas as pd
# import numpy as np
# def get_stock_for_buy(group):
#     top_n = group.nlargest(3, "label_pred")
#     return top_n.to_dict("records")

# def get_stock_for_sell(group):
#     top_n = group.nsmallest(3, "label_pred")
#     return top_n.to_dict("records")

# model_prediction = pd.read_pickle('./backtest_data/test/000016_20190101_回归任务.pkl')
# stock_for_buy = model_prediction.groupby("datetime").apply(get_stock_for_buy).to_dict()
# stock_for_sell = model_prediction.groupby("datetime").apply(get_stock_for_sell).to_dict()
